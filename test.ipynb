# %%
import pandas as pd 

pd.DataFrame({"voce": ["fitto", "gas", "luce", "acqua", "subtotale", "internet", "allarme", "subtotale", "tari", "ascensore", "totale"],
             "valore": [fitto, gas, luce, acqua, primo_subtotale_valore, internet, allarme, secondo_subtotale_valore, tari, ascensore, totale]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       2
#       3 pd.DataFrame({"voce": ["fitto", "gas", "luce", "acqua", "subtotale", "internet", "allarme", "subtotale", "tari", "ascensore", "totale"],
# ----> 4              "valore": [fitto, gas, luce, acqua, primo_subtotale_valore, internet, allarme, secondo_subtotale_valore, tari, ascensore, totale]})
#
# NameError: name 'fitto' is not defined
